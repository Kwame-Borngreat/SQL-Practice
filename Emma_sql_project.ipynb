# %%
# %load_ext sql

# %%
# %sql mysql+pymysql://root:asdfghjkl@localhost:3306/md_water_services
# Out:
# 'Connected: root@md_water_services'

# %%
# %config SqlMagic.displaylimit = None

# %% [markdown]
# # Cleaning My Data

# %%
# %%sql
# SELECT
#     *
# FROM
#     employee
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 56 rows affected.
# [(0, 'Amara Jengo', '+99637993287', 'amara.jengo@ndogowater.gov', '36 Pwani Mchangani Road', 'Sokoto', 'Ilanga', 'Field Surveyor'),
#  (1, 'Bello Azibo', '+99643864786', 'bello.azibo@ndogowater.gov', '129 Ziwa La Kioo Road', 'Kilimani', 'Rural', 'Field Surveyor'),
#  (2, 'Bakari Iniko', '+99222599041', 'bakari.iniko@ndogowater.gov', '18 Mlima Tazama Avenue', 'Hawassa', 'Rural', 'Field Surveyor'),
#  (3, 'Malachi Mavuso', '+99945849900', 'malachi.mavuso@ndogowater.gov', '100 Mogadishu Road', 'Akatsi', 'Lusaka', 'Field Surveyor'),
#  (4, 'Cheche Buhle', '+99381679640', 'cheche.buhle@ndogowater.gov', '1 Savanna Street', 'Akatsi', 'Rural', 'Field Surveyor'),
#  (5, 'Zuriel Matembo', '+99034075111', 'zuriel.matembo@ndogowater.gov', '26 Bahari Ya Faraja Road', 'Kilimani', 'Rural', 'Field Surveyor'),
# ...

# %%
## Keen Observations were most of the employees are our field surveyors

# %%
# %%sql
# SELECT
#     employee_name,
#     lOWER(REPLACE(employee_name, ' ','.') )
#  FROM
#      employee
# LIMIT 10;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 10 rows affected.
# [('Amara Jengo', 'amara.jengo'),
#  ('Bello Azibo', 'bello.azibo'),
#  ('Bakari Iniko', 'bakari.iniko'),
#  ('Malachi Mavuso', 'malachi.mavuso'),
#  ('Cheche Buhle', 'cheche.buhle'),
#  ('Zuriel Matembo', 'zuriel.matembo'),
#  ('Deka Osumare', 'deka.osumare'),
#  ('Lalitha Kaburi', 'lalitha.kaburi'),
#  ('Enitan Zuri', 'enitan.zuri'),
#  ('Farai Nia', 'farai.nia')]

# %%
## From here, I can add my concatenation function to the results to get my emails

# %%
# %%sql
#  SELECT
#     employee_name,
# CONCAT(
#     LOWER(REPLACE(employee_name, ' ', '.')), '@ndogowater.gov')
# FROM
#     employee
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 56 rows affected.
# [('Amara Jengo', 'amara.jengo@ndogowater.gov'),
#  ('Bello Azibo', 'bello.azibo@ndogowater.gov'),
#  ('Bakari Iniko', 'bakari.iniko@ndogowater.gov'),
#  ('Malachi Mavuso', 'malachi.mavuso@ndogowater.gov'),
#  ('Cheche Buhle', 'cheche.buhle@ndogowater.gov'),
#  ('Zuriel Matembo', 'zuriel.matembo@ndogowater.gov'),
#  ('Deka Osumare', 'deka.osumare@ndogowater.gov'),
#  ('Lalitha Kaburi', 'lalitha.kaburi@ndogowater.gov'),
#  ('Enitan Zuri', 'enitan.zuri@ndogowater.gov'),
#  ('Farai Nia', 'farai.nia@ndogowater.gov'),
#  ('Gamba Shani', 'gamba.shani@ndogowater.gov'),
#  ('Harith Nyota', 'harith.nyota@ndogowater.gov'),
#  ('Isoke Amani', 'isoke.amani@ndogowater.gov'),
#  ('Jengo Tumaini', 'jengo.tumaini@ndogowater.gov'),
#  ('Kunto Asha', 'kunto.asha@ndogowater.gov'),
#  ('Lesedi Kofi', 'lesedi.kofi@ndogowater.gov'),
#  ('Makena Thabo', 'makena.thabo@ndogowater.gov'),
# ...

# %%
##Neatly done. We can go ahead and update or database

# %%
####I have already updated the email column in my work so running it again here on jupyter will yield errors
###I will still add the code for reference
--UPDATE md_water_services.employee
--SET email= CONCAT(LOWER(REPLACE(employee_name, ' ', '.')), '@ndogowater.gov')


-- UPDATE md_water_services.employee 
--SET phone_number = RTRIM(phone_number)
### Next thing is to check the number of workers living in rural areas in Maji Ndogo

# %%
# %%sql
# SELECT
#     town_name,
#     COUNT(employee_name) AS number_of_employees
#
# FROM employee
# GROUP BY town_name
#
# ORDER BY number_of_employees DESC;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 9 rows affected.
# [('Rural', 29),
#  ('Dahabu', 6),
#  ('Harare', 5),
#  ('Lusaka', 4),
#  ('Zanzibar', 4),
#  ('Ilanga', 3),
#  ('Serowe', 3),
#  ('Kintampo', 1),
#  ('Yaounde', 1)]

# %%
#Clearly we can see, 29 work in Rural areas
# Finding workaholics, we can use the number of visit_counts to check their performances 

#and also track their IDS to get their identities
#we have to aggregate the visit_counts

# %% [markdown]
# # BEST WORKERS

# %%
# %%sql
#
#
# SELECT
#     assigned_employee_id,
#     visit_count
# FROM visits
# LIMIT 20;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 20 rows affected.
# [(12, 1),
#  (46, 1),
#  (40, 1),
#  (1, 1),
#  (14, 1),
#  (40, 1),
#  (30, 1),
#  (34, 1),
#  (6, 1),
#  (36, 1),
#  (16, 1),
#  (26, 1),
#  (1, 1),
#  (32, 1),
#  (6, 1),
#  (32, 1),
#  (48, 1),
#  (40, 1),
#  (12, 1),
#  (30, 1)]

# %%
# %%sql
#
#
# SELECT
#     assigned_employee_id,
#    COUNT(visit_count) AS number_of_employee_visits
# FROM visits
# GROUP BY assigned_employee_id
# ORDER BY number_of_employee_visits ASC
# LIMIT 3;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 3 rows affected.
# [(20, 15), (22, 143), (44, 218)]

# %% [markdown]
# Top three field surveyors are 1,30 and 34

# %%
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 2 rows affected.
# [(20, 'Kunto Asha', 'kunto.asha@ndogowater.gov', '+99176320477'),
#  (22, 'Lesedi Kofi', 'lesedi.kofi@ndogowater.gov', '+99611183730')]

# %%
# %%sql
# SELECT
#     type_of_water_source
#     SUM(number_of_people_served) AS population_served
# FROM
#     water_source
# WHERE type_of_water_source LIKE "%tap%"
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# (pymysql.err.ProgrammingError) (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'SUM(number_of_people_served) AS population_served\nFROM\n    water_source\nWHERE ty' at line 3")
# [SQL: SELECT
#     type_of_water_source
#     SUM(number_of_people_served) AS population_served
# FROM
#     water_source
# WHERE type_of_water_source LIKE "%%tap%%"]
# (Background on this error at: http://sqlalche.me/e/14/f405)

# %% [markdown]
# # ANALYSING LOCATION

# %%
#GOALS
#NUMBER OF RECORDS PER TOWN AND PER PROVINCE

# %%
# %%sql
# SELECT
#     town_name,
#     COUNT(town_name) AS records_per_town
# FROM
#     location
# GROUP BY town_name
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 25 rows affected.
# [('Harare', 1650),
#  ('Kintampo', 780),
#  ('Lusaka', 1070),
#  ('Rural', 23740),
#  ('Abidjan', 400),
#  ('Amina', 1090),
#  ('Asmara', 930),
#  ('Bello', 400),
#  ('Dahabu', 930),
#  ('Pwani', 520),
#  ('Deka', 350),
#  ('Djenne', 310),
#  ('Serowe', 480),
#  ('Yaounde', 270),
#  ('Zanzibar', 300),
#  ('Amara', 710),
#  ('Isiqalo', 770),
#  ('Mrembo', 990),
#  ('Zuri', 750),
#  ('Bahari', 470),
#  ('Cheche', 370),
#  ('Ilanga', 780),
#  ('Kofi', 510),
#  ('Majengo', 620),
#  ('Marang', 460)]

# %%
# %%sql
# SELECT
#     province_name,
#     COUNT(province_name) AS records_per_province
# FROM
#     location
# GROUP BY province_name
# ORDER BY records_per_province DESC
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [('Kilimani', 9510),
#  ('Akatsi', 8940),
#  ('Sokoto', 8220),
#  ('Amanzi', 6950),
#  ('Hawassa', 6030)]

# %%
# %%sql
# SELECT
#     town_name,
#     province_name,
#     COUNT(town_name) AS records_per_town,
#     COUNT(province_name) AS records_per_province
#     FROM
#     location
#     GROUP BY town_name,province_name
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 31 rows affected.
# [('Harare', 'Akatsi', 800, 800),
#  ('Kintampo', 'Akatsi', 780, 780),
#  ('Lusaka', 'Akatsi', 1070, 1070),
#  ('Rural', 'Akatsi', 6290, 6290),
#  ('Abidjan', 'Amanzi', 400, 400),
#  ('Amina', 'Amanzi', 670, 670),
#  ('Asmara', 'Amanzi', 930, 930),
#  ('Bello', 'Amanzi', 400, 400),
#  ('Dahabu', 'Amanzi', 930, 930),
#  ('Pwani', 'Amanzi', 520, 520),
#  ('Rural', 'Amanzi', 3100, 3100),
#  ('Amina', 'Hawassa', 420, 420),
#  ('Deka', 'Hawassa', 350, 350),
#  ('Djenne', 'Hawassa', 310, 310),
#  ('Rural', 'Hawassa', 3900, 3900),
#  ('Serowe', 'Hawassa', 480, 480),
#  ('Yaounde', 'Hawassa', 270, 270),
#  ('Zanzibar', 'Hawassa', 300, 300),
#  ('Amara', 'Kilimani', 710, 710),
#  ('Harare', 'Kilimani', 850, 850),
#  ('Isiqalo', 'Kilimani', 770, 770),
#  ('Mrembo', 'Kilimani', 990, 990),
#  ('Rural', 'Kilimani', 5440, 5440),
#  ('Zuri', 'Kilimani', 750, 750),
#  ('Bahari', 'Sokoto', 470, 470),
# ...

# %%
# %%sql
# SELECT
#     location_type,
#     COUNT(location_type) AS number_of_location
# FROM
#     location
# GROUP BY location_type
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 2 rows affected.
# [('Urban', 15910), ('Rural', 23740)]

# %% [markdown]
# ### DIVING INTO THE SOURCES

# %%
# %%sql
# #question1
# SELECT
#     SUM(number_of_people_served)
# FROM
#     water_source
# LIMIT 10;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 1 rows affected.
# [(Decimal('27628140'),)]

# %%
# %%sql
# SELECT
#     *
# FROM
#     water_source
# LIMIT 10;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 10 rows affected.
# [('AkHa00000224', 'tap_in_home', 956),
#  ('AkHa00001224', 'tap_in_home_broken', 930),
#  ('AkHa00002224', 'tap_in_home_broken', 486),
#  ('AkHa00003224', 'well', 364),
#  ('AkHa00004224', 'tap_in_home_broken', 942),
#  ('AkHa00005224', 'tap_in_home', 736),
#  ('AkHa00006224', 'tap_in_home', 882),
#  ('AkHa00007224', 'tap_in_home', 554),
#  ('AkHa00008224', 'well', 398),
#  ('AkHa00009224', 'well', 346)]

# %%
# %%sql
# SELECT
#     type_of_water_source,
#     COUNT(type_of_water_source) AS total_people_served
# FROM
#     water_source
# GROUP BY type_of_water_source
# ORDER BY total_people_served DESC;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [('well', 17383),
#  ('tap_in_home', 7265),
#  ('tap_in_home_broken', 5856),
#  ('shared_tap', 5767),
#  ('river', 3379)]

# %%
# %%sql
# SELECT
#     type_of_water_source,
#     ROUND(AVG(number_of_people_served)) AS aver_num_people_served
#
# FROM
#     water_source
# GROUP BY type_of_water_source
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [('tap_in_home', Decimal('644')),
#  ('tap_in_home_broken', Decimal('649')),
#  ('well', Decimal('279')),
#  ('shared_tap', Decimal('2071')),
#  ('river', Decimal('699'))]

# %%
# %%sql
# SELECT
#     type_of_water_source,
#     SUM(number_of_people_served) AS total_people_per_source
#
# FROM
#     water_source
# GROUP BY type_of_water_source
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [('tap_in_home', Decimal('4678880')),
#  ('tap_in_home_broken', Decimal('3799720')),
#  ('well', Decimal('4841724')),
#  ('shared_tap', Decimal('11945272')),
#  ('river', Decimal('2362544'))]

# %%
# %%sql
# SELECT
#     type_of_water_source,
#     SUM(number_of_people_served) AS total_people_per_source,
#     round(SUM(number_of_people_served)/
#           (SELECT SUM(number_of_people_served) FROM water_source) *100) AS Share_Percentage
# FROM
#     water_source
# GROUP BY
#     type_of_water_source
# ORDER BY Share_Percentage DESC;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [('shared_tap', Decimal('11945272'), Decimal('43')),
#  ('well', Decimal('4841724'), Decimal('18')),
#  ('tap_in_home', Decimal('4678880'), Decimal('17')),
#  ('tap_in_home_broken', Decimal('3799720'), Decimal('14')),
#  ('river', Decimal('2362544'), Decimal('9'))]

# %% [markdown]
# # SOLUTION

# %%
# %%sql
# SELECT
#     type_of_water_source,
#     SUM(number_of_people_served) AS total_people_per_source,
# RANK () OVER(
#     ORDER BY SUM(number_of_people_served) DESC
#     ) AS Rank_by_total_people_per_source
# FROM
#     water_source
# WHERE
#     type_of_water_source<>"tap_in_home"
# GROUP BY type_of_water_source
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 4 rows affected.
# [('shared_tap', Decimal('11945272'), 1),
#  ('well', Decimal('4841724'), 2),
#  ('tap_in_home_broken', Decimal('3799720'), 3),
#  ('river', Decimal('2362544'), 4)]

# %%
# %%sql
# SELECT
#     source_id,
#     type_of_water_source,
#     (number_of_people_served),
# RANK() OVER(
#     PARTITION by type_of_water_source
#     ORDER BY(number_of_people_served) DESC
#     ) AS priority_rank
# FROM
#     water_source
# WHERE
#     type_of_water_source<>"tap_in_home"
# LIMIT 10;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 10 rows affected.
# [('SoRu34798224', 'river', 998, 1),
#  ('SoRu35837224', 'river', 998, 1),
#  ('SoRu36238224', 'river', 998, 1),
#  ('SoRu36791224', 'river', 998, 1),
#  ('SoRu36880224', 'river', 998, 1),
#  ('SoRu38142224', 'river', 998, 1),
#  ('SoRu37756224', 'river', 998, 1),
#  ('SoMa33775224', 'river', 998, 1),
#  ('KiRu30353224', 'river', 998, 1),
#  ('SoIl32972224', 'river', 998, 1)]

# %% [markdown]
# # ANALYSING QUEUES

# %%
# %%sql
#
# SELECT
#     *
#
# FROM visits
# LIMIT 10;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 10 rows affected.
# [(0, 'SoIl32582', 'SoIl32582224', datetime.datetime(2021, 1, 1, 9, 10), 1, 15, 12),
#  (1, 'KiRu28935', 'KiRu28935224', datetime.datetime(2021, 1, 1, 9, 17), 1, 0, 46),
#  (2, 'HaRu19752', 'HaRu19752224', datetime.datetime(2021, 1, 1, 9, 36), 1, 62, 40),
#  (3, 'AkLu01628', 'AkLu01628224', datetime.datetime(2021, 1, 1, 9, 53), 1, 0, 1),
#  (4, 'AkRu03357', 'AkRu03357224', datetime.datetime(2021, 1, 1, 10, 11), 1, 28, 14),
#  (5, 'KiRu29315', 'KiRu29315224', datetime.datetime(2021, 1, 1, 10, 17), 1, 9, 40),
#  (6, 'AkRu05234', 'AkRu05234224', datetime.datetime(2021, 1, 1, 10, 18), 1, 0, 30),
#  (7, 'KiRu28520', 'KiRu28520224', datetime.datetime(2021, 1, 1, 10, 28), 1, 0, 34),
#  (8, 'HaZa21742', 'HaZa21742224', datetime.datetime(2021, 1, 1, 10, 37), 1, 0, 6),
#  (9, 'AmDa12214', 'AmDa12214224', datetime.datetime(2021, 1, 1, 10, 58), 1, 0, 36)]

# %%
# %%sql
# SELECT
#     SUBSTRING( MIN(time_of_record),1,10) AS Survey_Starts,
#     SUBSTRING(Max(time_of_record),1,10)  AS Survey_Ends,
#     DATEDIFF(Max(time_of_record),MIN(time_of_record))
#
# FROM visits
#
# LIMIT 10;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 1 rows affected.
# [('2021-01-01', '2023-07-14', 924)]

# %%
#AVERAGE QUEUE TIME

# %%
# %%sql
# SELECT
# AVG(time_in_queue) AS avg_queue_time_in_minutes
# FROM visits
# WHERE time_in_queue<>0
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 1 rows affected.
# [(Decimal('123.2574'),)]

# %%
# %%sql
# SELECT
#     AVG(NULLIF(time_in_queue,0)) AS avg_queue_time_in_minutes
# FROM visits
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 1 rows affected.
# [(Decimal('123.2574'),)]

# %%
# %%sql
# SELECT
#     DAYNAME(time_of_record) AS Day_of_week,
#     round(AVG(time_in_queue)) AS average_queue_time
#
# FROM
#     visits
# GROUP BY DAYNAME(time_of_record)
# ORDER BY round(AVG(time_in_queue)) DESC
# LIMIT 10;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 7 rows affected.
# [('Saturday', Decimal('246')),
#  ('Sunday', Decimal('82')),
#  ('Monday', Decimal('60')),
#  ('Friday', Decimal('53')),
#  ('Tuesday', Decimal('47')),
#  ('Thursday', Decimal('46')),
#  ('Wednesday', Decimal('43'))]

# %%
# %%sql
# SELECT
#     TIME_FORMAT(TIME(time_of_record),"%H:00" )AS time_of_the_day,
#     round(AVG(time_in_queue)) AS average_queue_time
#
# FROM
#     visits
# WHERE time_in_queue <>0
# GROUP BY TIME_FORMAT(TIME(time_of_record),"%H:00" )
# ORDER BY time_of_the_day
# LIMIT 24;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 14 rows affected.
# [('06:00', Decimal('149')),
#  ('07:00', Decimal('149')),
#  ('08:00', Decimal('149')),
#  ('09:00', Decimal('118')),
#  ('10:00', Decimal('114')),
#  ('11:00', Decimal('111')),
#  ('12:00', Decimal('112')),
#  ('13:00', Decimal('115')),
#  ('14:00', Decimal('114')),
#  ('15:00', Decimal('114')),
#  ('16:00', Decimal('114')),
#  ('17:00', Decimal('149')),
#  ('18:00', Decimal('147')),
#  ('19:00', Decimal('168'))]

# %%
# %%sql
# SELECT
# CONCAT(monthname(time_of_record), " ", day(time_of_record), ", ", year(time_of_record))
# FROM visits
# LIMIT 2;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 2 rows affected.
# [('January 1, 2021',), ('January 1, 2021',)]

# %%
# %%sql
# SELECT CONCAT(day(time_of_record), " ", monthname(time_of_record), " ", year(time_of_record)) FROM visits
# LIMIT 4;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 4 rows affected.
# [('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',),
#  ('1 January 2021',)]

# %%
# %%S
#
# SELECT
#     location_id,
#     time_in_queue,
#     AVG(time_in_queue) OVER (PARTITION BY location_id ORDER BY visit_count) AS total_avg_queue_time
# FROM
#     visits
# WHERE
# visit_count > 1 -- Only shared taps were visited > 1
# ORDER BY
#     location_id, time_of_record;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 20496 rows affected.
# [('AkHa00036', 113, Decimal('113.0000')),
#  ('AkHa00036', 229, Decimal('171.0000')),
#  ('AkHa00036', 400, Decimal('247.3333')),
#  ('AkHa00036', 120, Decimal('215.5000')),
#  ('AkHa00036', 185, Decimal('209.4000')),
#  ('AkHa00036', 158, Decimal('200.8333')),
#  ('AkHa00036', 226, Decimal('204.4286')),
#  ('AkHa00090', 50, Decimal('50.0000')),
#  ('AkHa00090', 63, Decimal('56.5000')),
#  ('AkHa00090', 12, Decimal('41.6667')),
#  ('AkHa00090', 62, Decimal('46.7500')),
#  ('AkHa00090', 53, Decimal('48.0000')),
#  ('AkHa00090', 34, Decimal('45.6667')),
#  ('AkHa00090', 40, Decimal('44.8571')),
#  ('AkHa00103', 186, Decimal('186.0000')),
#  ('AkHa00103', 88, Decimal('137.0000')),
#  ('AkHa00103', 237, Decimal('170.3333')),
#  ('AkHa00103', 141, Decimal('163.0000')),
#  ('AkHa00103', 183, Decimal('167.0000')),
#  ('AkHa00103', 179, Decimal('169.0000')),
#  ('AkHa00103', 387, Decimal('200.1429')),
# ...

# %%
# %%sql
# SELECT
# TIME_FORMAT(TIME(time_of_record), '%H:00') AS hour_of_day,
# -- Sunday
# ROUND(AVG(
# CASE
# WHEN DAYNAME(time_of_record) = 'Sunday' THEN time_in_queue
# ELSE NULL
# END
# ),0) AS Sunday,
#
# ROUND(AVG(
# CASE
# WHEN DAYNAME(time_of_record) = 'Monday' THEN time_in_queue
# ELSE NULL
# END
# ),0) AS Monday
#
# ROUND(AVG(
# CASE
# WHEN DAYNAME(time_of_record) = 'Tuesday' THEN time_in_queue
# ELSE NULL
# END
# ),0) AS Tuesday
#
# ROUND(AVG(
# CASE
# WHEN DAYNAME(time_of_record) = 'Wednesday' THEN time_in_queue
# ELSE NULL
# END
# ),0) AS Wednesday
#
#
# ROUND(AVG(
# CASE
# WHEN DAYNAME(time_of_record) = 'Thursday' THEN time_in_queue
# ELSE NULL
# END
# ),0) AS Thursday
#
#
# ROUND(AVG(
# CASE
# WHEN DAYNAME(time_of_record) = 'Friday' THEN time_in_queue
# ELSE NULL
# END
# ),0) AS Friday
#
#
# ROUND(AVG(
# CASE
# WHEN DAYNAME(time_of_record) = 'Saturday' THEN time_in_queue
# ELSE NULL
# END
# ),0) AS Saturday
#
# From Visits;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# (pymysql.err.ProgrammingError) (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'ROUND(AVG(\nCASE\nWHEN DAYNAME(time_of_record) = 'Tuesday' THEN time_in_queue\nELSE' at line 18")
# [SQL: SELECT
# TIME_FORMAT(TIME(time_of_record), '%%H:00') AS hour_of_day,
# -- Sunday
# ROUND(AVG(
# CASE
# WHEN DAYNAME(time_of_record) = 'Sunday' THEN time_in_queue
# ELSE NULL
# END
# ),0) AS Sunday,
#
# ROUND(AVG(
# CASE
# WHEN DAYNAME(time_of_record) = 'Monday' THEN time_in_queue
# ELSE NULL
# END
# ),0) AS Monday
#
# ROUND(AVG(
# CASE
# WHEN DAYNAME(time_of_record) = 'Tuesday' THEN time_in_queue
# ELSE NULL
# END
# ),0) AS Tuesday
#
# ROUND(AVG(
# CASE
# WHEN DAYNAME(time_of_record) = 'Wednesday' THEN time_in_queue
# ELSE NULL
# END
# ),0) AS Wednesday
#
#
# ROUND(AVG(
# CASE
# WHEN DAYNAME(time_of_record) = 'Thursday' THEN time_in_queue
# ...
